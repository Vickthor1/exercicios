# %% [markdown]
# <br>
# Jogo de bar que se chama Bar do Russo, as escolhas serÃ£o feitas com opÃ§Ãµes numÃ©ricas de acordo com o avanÃ§o do game. <br>

# %%
import pyfiglet

# %%
from colorama import Fore, init

# %%
init()

# %%
import sys,time,random

# %%
def sprint(str):
   for c in str + '\n':
     sys.stdout.write(c)
     sys.stdout.flush()
     time.sleep(1./90)

# %%
result = pyfiglet.figlet_format("Boteco do Russo", font = "banner3-D" ) 
sprint(result)
# Out:
# '########:::'#######::'########:'########::'######:::'#######::
#  ##.... ##:'##.... ##:... ##..:: ##.....::'##... ##:'##.... ##:
#  ##:::: ##: ##:::: ##:::: ##:::: ##::::::: ##:::..:: ##:::: ##:
#  ########:: ##:::: ##:::: ##:::: ######::: ##::::::: ##:::: ##:
#  ##.... ##: ##:::: ##:::: ##:::: ##...:::: ##::::::: ##:::: ##:
#  ##:::: ##: ##:::: ##:::: ##:::: ##::::::: ##::: ##: ##:::: ##:
#  ########::. #######::::: ##:::: ########:. ######::. #######::
# ........::::.......::::::..:::::........:::......::::.......:::
# '########:::'#######:::::'########::'##::::'##::'######:::'######:::'#######::
#  ##.... ##:'##.... ##:::: ##.... ##: ##:::: ##:'##... ##:'##... ##:'##.... ##:
#  ##:::: ##: ##:::: ##:::: ##:::: ##: ##:::: ##: ##:::..:: ##:::..:: ##:::: ##:
#  ##:::: ##: ##:::: ##:::: ########:: ##:::: ##:. ######::. ######:: ##:::: ##:
#  ##:::: ##: ##:::: ##:::: ##.. ##::: ##:::: ##::..... ##::..... ##: ##:::: ##:
# ...

# %%
def sprint(str):
   for c in str + '\n':
     sys.stdout.write(c)
     sys.stdout.flush()
     time.sleep(3./90)

# %%
while True:
   sprint(
      'Bem vindo ao "Boteco don Russo", '
      'como todo o lugar infelizmente a falha Ã© algo inevitavel, mas aqui nesse game Ã© evitavel'
      ' toda a vez que vocÃª falhar, vocÃª volta ao vai ter que fazer o game todo de novo, tenha cuidado com quem conversa'
      ' (as escolhas seram feitas com atalho rÃ¡pido, nas escolhas sem numeraÃ§Ã£o responda o que quiser. Sistema de dinheiro, barra de bebida e modo de jogo, nÃ£o inclusos nem nessa demo e nem na de dia 18 de novembro)'
   )
   print('')
   sprint(Fore.RED + ' !!!ATENÃ‡ÃƒO JOGO HUMORISTICO, QUALQUER SEMELHANÃ‡A COM ALGO REAL Ã‰ MERA CONHECIDENCIA!!! ')
# Out:
# Bem vindo ao "Boteco don Russo", como todo o lugar infelizmente a falha Ã© algo inevitavel, mas aqui nesse game Ã© evitavel toda a vez que vocÃª falhar, vocÃª volta ao vai ter que fazer o game todo de novo, tenha cuidado com quem conversa (as escolhas seram feitas com atalho rÃ¡pido, nas escolhas sem numeraÃ§Ã£o responda o que quiser. Sistema de dinheiro, barra de bebida e modo de jogo, nÃ£o inclusos nem nessa demo e nem na de dia 18 de novembro)
#
#  !!!ATENÃ‡ÃƒO JOGO HUMORISTICO, QUALQUER SEMELHANÃ‡A COM ALGO REAL Ã‰ MERA CONHECIDENCIA!!!
# Bem vindo ao "Boteco don Russo", como todo o lugar infelizmente a falha Ã© algo inevitavel, mas aqui nesse game Ã© evitavel toda a vez que vocÃª falhar, vocÃª volta ao vai ter que fazer o game todo de novo, tenha cuidado com quem conversa (as escolhas seram feitas com atalho rÃ¡pido, nas escolhas sem numeraÃ§Ã£o responda o que quiser. Sistema de dinheiro, barra de bebid

# %%
   #IntroduÃ§Ã£o do jogo

# %%
   print(Fore.RESET + '')
   nome = input('Qual o seu nome? ')
   print('')
   sprint('Chegou a sexta feira, dia da semana que o filho chora e a mÃ£e nÃ£o vÃª, '
         f'{nome} quer curtir a sua grande noite com tudo que ela pode oferecer,'
         )
   sprint('VocÃª vÃª que tem um bar novo')

# %%
   comeÃ§o = True

# %%
   veiculo = False

# %%
   while comeÃ§o:
      print('')
      bar = input('(1)VocÃª quer ir a esse bar ou (2)nÃ£o ir e ficar em casa? ')
      if bar == '1':
         print('')
         sprint('VocÃª decide ir ao bar novo')
         print('')
         veiculo = True
         break
      elif bar == '2':
         print('')
         sprint('VocÃª decide ficar na sua casa assistindo sÃ©ria e comendo pipoca')
         print('')
         break
      else:
         print('')
         sprint('NÃ£o entendi(digite 1 ou 2)')
         pass

# %%
   moto = False
   andando = False
   dificuldade = False
   amigo = False

# %%
   while veiculo:
      veiculo_que_sera_usado = input('(1)vocÃª prefere ir andando ou (2)de moto? ')
      if veiculo_que_sera_usado == '1':
         amigo = True
         andando = True
         print('')
         sprint('vocÃª andou bastante atÃ© chegar no bar novo')
         print('')
         sprint(Fore.RED + 'INFORMAÃ‡Ã‚O GUARDADA!')
         print(Fore.RESET + '')
         break
      elif veiculo_que_sera_usado == '2':
         amigo = True
         moto = True
         print('')
         sprint('vocÃª chegou rapidinho no bar novo')
         print('')
         sprint(Fore.RED + 'INFORMAÃ‡Ã‚O GUARDADA!')
         break
      else:
         print(Fore.RESET + '')
         sprint('NÃ£o compreendi(digite 1 ou 2)')
         pass

# %%
   personagem1_Jack = False
   personagem1_Jackbravo1=False
   barman = False

# %%
   while amigo:
      print('')
      sprint(Fore.RESET + 'VocÃª vÃª que tem um amigo seu lÃ¡')
      print('')
      primeira_fala = input('(1)Vai cumprimenta-lo ou (2)nÃ£o? ')
      if primeira_fala == '1':
         personagem1_Jack = True
         print('')
         sprint('VocÃª decide falar com ele')
         print('')
         break
      elif primeira_fala == '2':
         barman = True
         print('')
         sprint('VocÃª ignora o Jack e logo vai falar com o barman')
         break
      else:
         print('')
         print('NÃ£o compreendi(digite 1 ou 2)')
         pass

# %%
   mapa = False

# %%
   while barman:
      print(Fore.RESET + '')
      sprint(Fore.CYAN + f'{nome}: OlÃ¡ boa noite, poderia me servir uma bebida?')
      print('')
      sprint(Fore.LIGHTBLACK_EX + 'Barman: Por que toda essa formalidade amigÃ£o, pode ficar Ã  vontade')
      print('')
      sprint(Fore.LIGHTBLACK_EX + 'Barman: Temos, vodka, cachaÃ§a, whisky, vinho, skol, heineken, brahma, Itaipava...')
      print('')
      sprint(Fore.RESET + 'VocÃª acaba nÃ£o prestando muita atenÃ§Ã£o nas outras coisas que ele diz')
      print('')
      bebida = input(Fore.CYAN + f'{nome}: Eu gostaria de pedir ')
      print('')
      sprint(Fore.RESET + 'VocÃª bate um papo com o Barman e ele te conta a HistÃ³ria do Bar e que ele e a filha dele reabriram o bar no Brasil, pelo fato do paÃ­s deles estarem em guerra e eles nÃ£o apoiarem isso')
      print('')
      sprint(Fore.LIGHTBLACK_EX + 'Barman: VocÃª Ã© um bom ouvinte meu jovem, meu nome Ã© Alexandre mas pode e chamar de Lex')
      print('')
      sprint(Fore.CYAN + f'{nome}: meu nome Ã© {nome}, prazer em conhecer o senhor')
      print('')
      explorar = input(Fore.RESET + 'VocÃª quer (1)explorar o mapa ou (2)quer ir para sua casa? ')
      if explorar == '1':
         mapa = True
         break
      elif explorar =='2':
         mapa = False
         break
      else:
         sprint(Fore.LIGHTRED_EX + 'SÃ³ nÃºmeros')
         pass
   #fim do dialogo com o Lex

# %%
   pergunta = False

# %%
   while personagem1_Jack:
      print(Fore.RESET + '')
      sprint(Fore.CYAN + f'{nome}: Fala ai Jack! ')
      print('')
      sprint(Fore.BLUE + 'Jack: Eae, veio aproveitar a sexta?')
      print('')
      sprint(Fore.CYAN + f'{nome}: Sim, essa semana foi tortura')
      print('')
      sprint(Fore.BLUE + 'Jack: Vou ficar aqui com vocÃª na mesa vlw? e me paga uma cerveja ai')
      print('')
      sprint(Fore.CYAN + f'{nome}: Mas Jack sou eu que to em pÃ©')
      print('')
      sprint(Fore.RESET + 'VocÃªs comeÃ§am a rir da situaÃ§Ã£o')
      print('')
      sprint(Fore.BLUE + 'Jack: Mas ai namoral, paga uma breja ai?')
      print('')
      decisam = input(Fore.RESET + '(1)Deixar Jack sÃ³zinho e explorar o mapa ou (2)bater um papo com Jack')
      if decisam == '1':
         print('')
         sprint(Fore.RESET + 'Jack, vou ter que vazar, vai dar nÃ£o')
         print('')
         mapa = True
         break
      elif decisam == '2':
         print('')
         sprint(Fore.CYAN + f'{nome}: Ta bom mano, desce uma cerveja pra esse maluco aqui!')
         print('')
         sprint(Fore.RESET + 'VocÃª olha pro banheiro feminino e tem uma leve impressam de ter visto um rosto conhecido indo pra dentro do banheiro')
         print('')
         sprint(Fore.BLUE + f'Jack: O que Ã© que foi hein {nome}, ta de olho em alguma gatinha? ')
         print('')
         pergunta = True
         break
      else:
         print(Fore.RESET + '')
         sprint('NÃºmeros por favor!')

# %%
   personagem1_JackSim = False
   personagem1_JackNÃ£o = False
   personagem1_Jackbravo = False
   Deixar_ele_sozinho = False
   Desculpas = False
   Porrada = False

# %%
   while pergunta:
      print(Fore.RESET + '')
      pandora = input('Chegou a hora, qual decisÃ£o serÃ¡ feita, vocÃª vai falar que (1)sim, vai dizer que (2)nÃ£o ou (3)Ser grosso')
      print('')
      if pandora =='1':
         personagem1_JackSim = True
         break
      elif pandora == '2':
         personagem1_JackNÃ£o = True
         break
      elif pandora == '3':
         personagem1_Jackbravo = True
         break
      else:
         print('')
         sprint(Fore.RESET + 'NÃºmeros por favor!')
         pass

# %%
   while personagem1_JackNÃ£o:
      print('')
      sprint(Fore.CYAN + f'{nome}: NÃ£o')
      print('')
      sprint(Fore.RESET + 'Jack nÃ£o acredita muito em vocÃª mas deixa quieto')
      print('')
      break

# %%
   while personagem1_JackSim:
      sprint(Fore.CYAN + f'{nome}: Sim')
      print('')
      sprint(Fore.RESET + 'Jack da um sorrisinho malicioso')
      print('')
      sprint(Fore.RESET + 'Jack, louco do jeito que Ã©, zoa falando pra vocÃª entrar no banheiro feminino quando ninguÃ©m estiver olhando')
      print('')
      resp = input(Fore.RESET + 'O que vocÃª vai decidir (1)Dar uma de maluco e entrar (2)NÃ£o fazer essa maluquice? ')
      if resp == '1':
         print('')
         sprint(Fore.CYAN + f'{nome}: Boa idÃ©ia')
         print('')
         sprint(Fore.RESET + 'VocÃª entra no banheiro feminino e avista sua ex e ela liga pra policia')
         print('')
         sprint(Fore.CYAN + f'{nome}: Desculpa, errei fui muleque')
         print('')
         sprint(Fore.RESET + 'VocÃª foi preso')
         break
      
      elif resp == '2':
         print('')
         sprint(Fore.CYAN + f'{nome}Vai se lascar, duente')
         print('')
         sprint(Fore.RESET + 'Jack acha engraÃ§ado')
         print('')
         sprint(Fore.RESET + 'vocÃª vai pra perto do banheiro feminino e vÃª sua...')
         sprint(Fore.RESET + 'VocÃª chegou ao limite da demo, para saber o desfecho dessa histÃ³ria apareÃ§a no dia 18 de novembro')
         break
      
      else:
         print('')
         sprint(Fore.RESET + 'NÃ£o tem essa opÃ§Ã£o')
         print('')
         pass

# %%
   while personagem1_Jackbravo:
      sprint(Fore.CYAN + f'{nome}:E o quico?')
      print('')
      sprint(Fore.BLUE + 'Jack: Ã‰ O QUE MENOR!? ')
      print('')
      sprint(Fore.RESET + 'Jack fica com muita raiva e bate na mesa')
      print('')
      sprint(Fore.RESET + 'Todo mundo do bar vira a atenÃ§Ã£o para vocÃªs')
      print('')
      personagem1_Jackbravo1 = True
      break

# %%
   while personagem1_Jackbravo1:
      resposta = input(sprint(Fore.RESET + 'O que vocÃª ira fazer? (1)Pedir desculpas e acalmar Jack (2)Descer a porrada no Jack ou (3)Deixar ele falando sozinho'))
      
      if resposta == '1':
         print('')
         sprint(Fore.CYAN + f'{nome}: Desculpa errei, fui muleke')
         Desculpas = True
         break
      
      elif resposta == '2':
         print('')
         sprint(Fore.CYAN + f'{nome}: Cala a boca maluco!!')
         print('')
         sprint(Fore.RESET + 'role os dados para ver se vocÃª tem sorte')
         Porrada = True
         break
      
      elif resposta == '3':
         Deixar_ele_sozinho = True
         break
      
      else:
         print('')
         sprint(Fore.BLUE + 'Jack: repete paspalho!!')
         pass

# %%
   while Desculpas:
      print('')
      sprint(Fore.RESET + 'Jack nÃ£o acredita muito em vocÃª, mas deixa quieto a situaÃ§Ã£o')
      break

# %%
   while Porrada:
      dado = random.randrange(1,6)
      if dado < 3:
         print('')
         sprint(Fore.LIGHTRED_EX + '+3 VocÃª da tanta porrada na cara do Jack que ele chora')
         print('')
         sprint(Fore.RESET + 'VocÃªs sÃ£o expulsos do bar e tem uma divida de 2 mil reais por danos')
         break
      else:
         print('')
         sprint(Fore.LIGHTRED_EX + '-3 VocÃª toma um Jab de esquerda e Ã© nocauteado')
         print('')
         sprint(Fore.RESET + 'VocÃªs sÃ£o expulsos do bar e tem uma divida de 2 mil reais por danos')
         break
         
   while Deixar_ele_sozinho:
      print('')
      sprint(Fore.RESET + 'VocÃª deixa Jack sÃ³zinho')
      print('')
      sprint(Fore.RED + 'INFORMAÃ‡ÃƒO GUARDADA!!')
      mapa = True
      break
   Lulu = False
   sentarnamesa = False
   bebercomLulu = False
   casacomLulu = False
   Guilherme = False
   Alice = False

# %%
   while mapa:
      print(Fore.RESET + '')
      sprint('(1)Ir para perto do banheiro Feminino ver se hÃ¡ alguma conhecida, (2)ir ao banheiro masculino ou (3)ir atÃ© o salÃ£o principal')
      respos = input('')
      if respos == '1':
         print('')
         Lulu = True
         break
      elif respos == '2':
         print('')
         sprint('VocÃª vai atÃ© o banheiro masculino')
         Guilherme = True
         break
      elif respos == '3':
         print('')
         sprint('VocÃª vai ao salÃ£o principal')
         sprint('VocÃª vÃª uma jovem cantando no palco e resolve se aproximar, vocÃª fica encantado com a voz dela ')
         print('')
         Alice = True
         break
      
      else:
         print('')
         sprint('SÃ³ tem esses lugares')
         pass
   grita = False
   deboa = False
   beber = False
   
   while Lulu:
      Lulubraba = input('VocÃª encontra sua ex namorada na frente do banheiro feminino, opÃ§Ã£o (1)falar com ela sÃ³ por educaÃ§Ã£o (2)ir embora')
      if Lulubraba == '2':
         print('')
         sprint('VocÃª vai pra casa') 
         break
      elif Lulubraba == '1':
         print('')
         sprint('VocÃªs conversam e ela pergunta se vocÃª nÃ£o quer se sentar Ã  mesa com ela') 
         print('')
         sentarnamesa = True
         break

# %%
   while sentarnamesa:
      senta = input('(1) NÃ£o, eu tÃ´ de boa, ir embora ou (2)Sim, o que poderia dar errado? ')
      if senta ==  '1':
         print('')
         sprint('Lulu fica meio cabisbaixa, mas deixa vocÃª ir embora')
         print('')
         break
      elif senta == '2': 
         print('')
         sprint('Nada demais, afinal vocÃª jÃ¡ sabe lidar com ela')
         print('')
         sprint('VocÃªs se sentam Ã  mesa e ela pede uma bebida')
         print('')
         bebercomLulu = True
         break
   while bebercomLulu:
      bebidinha = input(Fore.MAGENTA + f'Lulu: Quer uma bebida tambÃ©m {nome}? (1)Sim (2)NÃ£o ')
      if bebidinha == '1':
         print(Fore.RESET + '')
         sprint('Sim, quero me divertir')
         print('')
         sprint('Lulu vai ao banheiro')
         print('')
         sprint(' O garÃ§om anota os pedidos, mas quem leva o pedido atÃ© vocÃªs Ã© uma garÃ§onete, que tenta falar com vocÃª')
         print('')
         sprint(Fore.LIGHTGREEN_EX + 'GarÃ§onete: Notei que vocÃª estÃ¡ sozinho, desculpe incomodar mas vai fazer algo mais tarde?') 
         print('')
         sprint(Fore.RESET + 'Antes mesmo de vocÃª responder algoâ€¦') 
         print('')
         sprint(Fore.MAGENTA + 'Lulu: QUEM VOCÃŠ PENSA QUE Ã‰, SUA MOCRÃ‰IA ENSEBADA!') 
         print('')
         sprint(Fore.LIGHTGREEN_EX + 'GarÃ§onete: Calma moÃ§a vocÃª estÃ¡ se alterando')
         print('')
         sprint(Fore.RESET + 'Elas comeÃ§am a discutir e vocÃª acalma a Lulu, e se desculpa com a garÃ§onete') 
         print('')
         sprint('Lulu fica bolada com vocÃª, por vocÃª dar razÃ£o a garÃ§onete, e joga a bebida na sua cara!') 
         print('')
         sprint('A garÃ§onete trÃ¡s uma toalhinha para vocÃª se enxugar e a Lulu vÃª e fica fazendo birra  e vc vai embora')
         break

# %%
      elif bebidinha == '2':
         print('')
         sprint('NÃ£o, nÃ£o to muito afim de beber')
         print('')
         sprint('Lulu comeÃ§a a virar todas')
         print('')
         sprint(f'{nome}: Hei! Vai com calma')
         print('')
         sprint(Fore.MAGENTA + 'Lulu: Eu zeiuqui eu to fazenâ€¦')
         print(Fore.RESET + '')
         sprint('Lulu da uma soluÃ§ada, VocÃª vÃª que Lulu, nÃ£o estÃ¡ em condiÃ§Ãµes de ir pra casa, pois bebeu muito')
         print('')
         casacomLulu = True
         break
      
   while casacomLulu:
      casa = input('(1)Levar Lulu para a casa dela ou(2)Convidar Lulu para sua casa? ')
      if casa == '1':
         print('')
         sprint('ApÃ³s levar Lulu a casa dela, vocÃª vÃª que estÃ¡ tarde, e resolve ir pra sua casa ')
         print('')
         break
      elif casa == '2':
         print('')
         sprint('VocÃª deixa Lulu sÃ³bria') 
         print('')
         sprint('VocÃª e Lulu relembram os velhos tempos, "vendo netflix" na sua casa')
         print('')
         break
      
   while Alice:
      respalice = input('(1) VocÃª_Grita!! ou (2) ficar de boa e admirando')
      if respalice == '1':
         sprint('A cantora acha estranho a situaÃ§Ã£o, para de cantar e chama os seguranÃ§as')
         print('')
         sprint('VocÃª rapidamente percebe a situaÃ§Ã£o e tenta mentir')
         grita = True
         break
      
      elif respalice == '2':
         sprint('VocÃª fica de boa e admira, vocÃª quer tentar chamar a atenÃ§Ã£o dela de algum modo')
         print('')
         deboa = True
         break
      
      else:
         print('')
         sprint(Fore.RESET + 'NÃ£o tem essa opÃ§Ã£o')
         print('')
         pass
   
   while grita:
      print('')
      escolha = input('(1) vocÃª fala que e fiscal e estava testando a seguranÃ§a, (2)VocÃª se faz de doido para sair da situaÃ§Ã£o (3) VocÃª diz que Ã© de um show musical e quer falar com a cantora')
      if escolha == '1':
         sprint('SeguranÃ§as:CadÃª o seu cracha de fiscal?!')
         sprint('Os seguranÃ§as te tampam na porrada e te botam para fora do bar')
         break
      
      elif escolha == '2':
         sprint('O seguranÃ§a liga prara os mÃ©dicos psiquiatras(manicÃ´mio)!')
         print('')
         break
      
      elif escolha == '3':
         sprint('SeguranÃ§as:CadÃª o seu cracha de fiscal?!')
         sprint('Os seguranÃ§as te tampam na porrada e te botam para fora do bar')
         print('')
         break
      
      else:
         print('')
         sprint(Fore.RESET + 'NÃ£o tem essa opÃ§Ã£o')
         print('')
         pass
   apresentaalice1 = False
   apresentaalice = False
   dado1 = random.randrange(1,6)
   while deboa:
      respa = input('(1)VocÃª quer tentar duetar com ela ou (2)quer tentar uma troca de olhares?')
      if respa == '1':
         sprint(Fore.LIGHTRED_EX + 'rolagem de dados!!')
         if dado1 <= 3:
            print(Fore.RESET + '')
            sprint(' vocÃª canta tÃ£o desafinado que ela comeÃ§a a Rir')
            print('')
            sprint(' A cantora comeÃ§a a perder o ar de tanto rir e comeÃ§a a passar mal')
            print('')
            sprint('Os segura acabam vendo a cantora passando mal e ligam para a ambulÃ¢ncia')
            print('')
            sprint('Todo mundo fica te olhando e Jack fica bolado com vocÃª e te explana para o Barman')
            print('')
            sprint(' VocÃª e expulso do bar e vai ter que pagar o mÃ©dico da cantora')
            break
         elif dado1 > 3:
            print(Fore.RESET + '')
            sprint('VocÃª canta tÃ£o bem que ela se impressiona e te chama para o palco e te entrega um microfone')
            print('')
            sprint('apÃ³s o termino do show ela vai atÃ© vocÃª')
            apresentaalice = True
            break
         else:
            print('')
            sprint(Fore.RESET + 'NÃ£o tem essa opÃ§Ã£o')
            print('')
            pass
      elif respa == '2':
         print('')
         sprint('VocÃªs tem uma intensa troca de olhares')
         print('')
         sprint('VocÃªs trocam olhares e ela da um sorrisinho de leve para vocÃª')
         print('')
         sprint('apÃ³s o termino do show ela vai atÃ© vocÃª')
         apresentaalice = True
         break
   
   while apresentaalice:
      sprint('VocÃªs se sentam a mesa e comeÃ§am a conversar,vocÃª conta algumas piadas a ela')
      print('')
      sprint('VocÃªs conversam bastante, atÃ© que ela se apresenta...')
      print('')
      sprint(Fore.YELLOW + 'Alice: VocÃª Ã© muito engraÃ§ado alias,meu nome Ã© Alice qual eo seu ?')
      print('')
      sprint(Fore.CYAN + f'{nome}: Meu nome Ã© {nome} adorei vocÃª cantando no palco')
      print('')
      sprint(Fore.RESET + 'VocÃª descobre que o dono do bar Ã© o pai da Alice, e que ela ajuda o pai dela a gerar renda extra pro bar cantando')
      print('')
      apresentaalice1 = True
      break
   lulumaluca = False
   alicedialogoo = False
   situaÃ§Ã£o1 = False
   briga = False
   assalto = False
   mendigo = False
   while apresentaalice1:
      sprint('VocÃª vÃª que vocÃªs dois ja tem uma certa intimidade e o clima ficou bem sereno')
      print('')
      paquera = input('(1)VocÃª quer tentar paquerar a Alice (2)Deixar na amizade')
      
      if paquera == '1':
         sprint('Rolagem de dados!!!')
         lulumaluca = True
         break
      elif paquera == '2':
         sprint('vocÃªs ficam conversando e bebendo, depois disso vocÃª deixa ela em casa e segue seu caminho pra sua')
         break
   dado2 = random.randrange(1,6)
   
   while lulumaluca:
      
      if 3> dado2:
         sprint('Alice fica envergonhada e diz pra vocÃª ir com mais calma')
         print('')
         sprint('Lulu a sua ex estÃ¡ de olho no que vocÃª estava fazendo')
         print('')
         sprint(Fore.MAGENTA + 'Lulu: Conseguiu arrumar uma mocrÃ©ia Ã©, seu paspalho!')
         print('')
         sprint(Fore.RESET + 'Lulu tenta acabar com qualquer chance de amizade ou relacionamento de vocÃªs')
         print('')
         sprint(Fore.CYAN + f'{nome}: Para de ser infantiu, eu e vocÃª ja era, nÃ£o vÃª que estÃ¡ estragando a minha conversa com a  Alice')
         print('')
         sprint(Fore.MAGENTA + 'Lulu: VocÃª sabe bem que nenhuma outra mulher e melhor que euzinha aqui')
         print('')
         sprint(Fore.YELLOW + 'Alice te defende: NÃ£o se acha nÃ£o ele Ã© um cara bacana e merece mais do que uma maluca empacando as conversas dele')
         print('')
         sprint(Fore.RESET + 'Lulu tenta e puxar o cabelo de Alice e Alice da um murro na cara dela elas comeÃ§am a discutir e brigar')
         print('')
         sprint('Os seguranÃ§as aparecem e separam as duas')
         print('')
         sprint(Fore.MAGENTA + 'Lulu: Eu vou te pegar, eu sei onde vocÃª mora sua baranga!')
         print('')
         sprint(Fore.CYAN + f'{nome}: Alice me desculpa pela situaÃ§Ã£o eu nÃ£o queria que...')
         print('')
         sprint(Fore.YELLOW + 'Alice te enterrompe: Nossa, parece que eu vou ter que dormir fora hoje nÃ©')
         print('')
         sprint(Fore.RESET + 'VocÃª leva Alice pra sua casa e depois de um tempo vocÃªs se conhecem cada vez mais atÃ© que acabam morando juntos')
         print(Fore.RESET +'')
         andando = False
         break
      elif 3< dado2:
         sprint('ignorar e acha que foi sÃ³ impressÃ£o sua')
         print('')
         sprint( 'VocÃª sente uma energia meio ruim ali no ambiente, quando vocÃª ia avisar a Aliceâ€¦')
         print('')
         sprint(' A sua ex namorada Lulu aparece e puxa o cabelo de Alice e elas comeÃ§am a  discutir e brigar')
         print('')
         sprint('Lulu pega uma faca na mesa e ameaÃ§a vocÃªs dois, o que vocÃª vai fazer? ')
         print('')
         briga = True
         break
   
   while briga:
      ameaÃ§a = input('(1)Tentar reagir a tempo, (2)Puxar a Alice pela mÃ£o para sair dali  (3)Tentar chamar a atenÃ§Ã£o dos seguranÃ§as')
 
      if ameaÃ§a == '1':
         situaÃ§Ã£o1 = True
         break
      
      elif ameaÃ§a == '2':
         print('')
         sprint('VocÃª puxa Alice para fora do bar e fala para ela subir na sua moto')
         print('')
         sprint('VocÃªs dÃ£o uma longa volta pela cidade e param em um restaurante')
         print('')
         sprint('VocÃª conta para Alice sobre a Lulu e pede desculpas a ela, Alice fica tocada com a situaÃ§Ã£o')
         print('')
         sprint('Para compensar ela, vocÃª leva ela para a casa dela e ela te dÃ¡ um beijo e se despede de vocÃª agradecendo pela noite Ãºnica e maluca')
         print('')
         andando = False
         break
      elif ameaÃ§a == '3':
         print('')
         sprint('Os seguranÃ§as a levam')
         print('')
         sprint('Alice diz que depois vocÃªs vÃ£o rir da situaÃ§Ã£o mas quer distÃ¢ncia de vocÃª')
         print('')
         andando = False
         break
   dado3 = random.randrange(1,6)
   while situaÃ§Ã£o1:
         if dado3 <= 3:
            print('')
            sprint('VocÃª consegue desarmar Lulu a tempo mas ela comeÃ§a a gritar o que vai fazer?')
            alicedialogoo = True
            break
         else:
            print('')
            sprint('VocÃª nÃ£o consegue reagir a tempo e ela consegue ferir a Alice') 
            print('')
            sprint('Os seguranÃ§as veem a situaÃ§Ã£o ligam para uma ambulÃ¢ncia')
            print('')
            sprint('VocÃª vai para o hospital com ela e passa a noite lÃ¡')
            print('')
            sprint('Alice diz que depois eles vÃ£o rir da situaÃ§Ã£o mas quer distÃ¢ncia de vocÃª')
            andando = False
            break
   
   while alicedialogoo:
         print('')
         lulumaniaca = input('(1)tentar acalmar Lulu, (2)Deixar ela gritar enquanto os seguranÃ§as estÃ£o vindo?')
         
         if lulumaniaca == '1':
           print('')
           sprint('Lulu comeÃ§a a ir atÃ© vocÃª chorando, Lulu dÃ¡ umas pancadas no seu peito te xingando')
           print('')
           sprint('Tudo se resolve de forma pacÃ­fica, vocÃª ainda apresenta ela a Alice, que fica muito receosa')
           print('')
           sprint(' Sua noite foi toda tomando conta de Lulu, pra nÃ£o acontecer nenhum acidente, e sim, vocÃª volta com a sua ex')
           print('')
           andando = False
           break
         
         elif lulumaniaca == '2':
           print('')
           sprint('Os seguranÃ§as a levam')
           print('')
           sprint('Alice diz que depois vocÃªs vÃ£o rir da situaÃ§Ã£o mas quer distÃ¢ncia de vocÃª')
           print('')
           andando = False
           break
   
   while Guilherme:
      print(Fore.RESET + '')
      sprint('Chegando lÃ¡ vocÃª ouve uma voz dizendo: To sentindo cheiro de coelinho rosa')
      print('')
      grandam = input('O que vocÃª irÃ¡ fazer??!! (1)Fugir (2)ficar e encarar (3)fingir que nÃ£o ouviu')
      if grandam == '1':
         print('')
         sprint('VocÃª corre pra caramba e vai pra casa')
         break
      
      elif grandam == '2':
         sprint(Fore.LIGHTMAGENTA_EX + 'Desconhecido: Senti sua falta nos treinos')
         print('')
         sprint(Fore.CYAN + f'{nome}: Espera ai, Guilherme?')
         print('')
         sprint(Fore.LIGHTMAGENTA_EX + 'Guilherme: Quer fazer um agachamante nÃ£o? ')
         print('')
         sprint(Fore.CYAN + f'{nome}: VocÃª bebeu vodka ou agua de coco?')
         print('')
         sprint(Fore.LIGHTMAGENTA_EX + 'Guilherme: Pra mim tanto faz')
         print('')
         sprint(Fore.LIGHTMAGENTA_EX + 'Guilherme: Quer beber comigo? ')
         print(Fore.RESET + '')
         beber = True
         andando = False
         break
      
      elif grandam == '3':
         sprint(Fore.RESET + 'VocÃª sente uma mÃ£o no seu ombro')
         sprint('vocÃª vira pra trÃ¡s e Ã© Guilherme seu amigo da academia ')
         print('')
         sprint(Fore.CYAN + f'{nome}: Qual Ã© Guilherme ta de vacilaÃ§Ã£o')
         print('')
         sprint(Fore.LIGHTMAGENTA_EX + 'Guilherme: Ta faltando bastante nos treinos hein ')
         print('')
         sprint(Fore.CYAN + f'{nome}: Cara to sem foco na academia')
         print('')
         sprint(Fore.LIGHTMAGENTA_EX + 'Guilherme te faz um discurso motivacional para vocÃª se animar pra ir a academia e depois despenca no chÃ£o')
         print('')
         sprint(Fore.RESET + 'VocÃª chama uma hambulancia pra ele, depois disso vocÃª vÃª que estÃ¡ tarde e volta pra sua casa')
         andando = False
         break
      
      else:
         print('')
         sprint(Fore.RESET + 'NÃºmeros por favor!')
         pass

# %%
   while beber:
      beberres = input(Fore.RESET + '(1)VocÃª vai beber com Ghilherme ou (2)Vai tentar deixa-lo sÃ³brio')
      
      if beberres == '1':
         print('')
         print(Fore.RESET + '')
         sprint('VocÃªs beberam a noite toda e esqueceram do resto, vocÃª acordano dia seguinte na cama do guilherme sem sentir suas pernas direito, vocÃª olha o grupo da empresa e jack vazou seus videos com o guilherme no bar')
         andando = False
         break
      
      elif beberres == '2':
         print('')
         sprint('VocÃª vai trocando a vodka dele por Ã¡gua e deixand ele sÃ³brio, apÃ³s isso deixa ele na casa dele')
         break
      
      else:
         print('')
         sprint('NÃºmeros apenas!')
         pass
   
   while andando:
      print(Fore.RESET + '')
      sprint('VocÃª foi andando pra casa, durante o caminho um mendingo te aborda com um pedaÃ§ de pau na mÃ£o')
      print('')
      sprint('Mendigo: Celular e carteira por favor!!')
      print('')
      assalto = input('(1)reagir e tampar ele na porrada, (2)Dar a carteira pra ele? ')
      if assalto == '1':
       sprint('ROLAGEM DE DADOS!!!')
       dado4 = random.randrange(1,6)
       mendigo = True
       break
      elif assalto == '2':
       sprint(f'{nome}: Toma pode ficar')
       print('')
       sprint('VocÃª vai pra casa sem a carteira')
       print('')
       break
      else:
         print('')
         sprint('NÃºmeros apenas!')
         pass
   while mendigo:
      if dado4 <= 3:
         sprint('O mendigo da uma paulada na sua cabeÃ§a, rouba sua carteira e vai embora')
         print('')
         break
      else:
         sprint('VocÃª da uma voadora no mendingo, tampa ele na porrada, liga pra policia e ele vai preso (por favor nÃ£o reaja a assaltos, tenha amor a sua vida e familia)')
         print('')
         break
 
   while moto:
      print('')
      sprint(Fore.RED + 'SE BEBER NÃƒO DIRIJA!!!!')
      print(Fore.RESET + '')
      break
   
   result = pyfiglet.figlet_format("Fim de jogo! Obrigado Por jogar!", font = "digital" ) 
   sprint(Fore.RED + result)
   
   print(Fore.RESET + '')
   sprint('------CrÃ©ditos Finais----')
   sprint('ProgramaÃ§Ã£o, roteiro e historia por Victor Hugo Oliveira')
   sprint('HistÃ³ria e roteiro por Igor Silva azeredo')
   sprint('ParticipaÃ§Ã£o especial Gabriel de Souza Brito')
   print('')
   Encerrarmento = True
   
   encerrar = sprint(Fore.RED + 'Digite 1 para sair ') 
   encerrar = input(Fore.YELLOW + 'ou aperte enter para jogar novamente ')
   if encerrar == '':
      print('')
      sprint(Fore.RESET + 'AtÃ© logo!')
      print('')
      pass
   else:
      print('')
      sprint(Fore.RESET + 'Tchau!')
      break
